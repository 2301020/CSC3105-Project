# %% [markdown]
# <a href="https://colab.research.google.com/github/2301020/CSC3105-Project/blob/main/UoG-DA_Group28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UoG-DA_Group28 Jupyter Notebook

# %% [markdown]
# <hr>

# %% [markdown]
# ## <u> Data Pre-Processing </u>

# %% [markdown]
# ### Library Imports and Misc. Setup

# %% [markdown]
# This code block defines essential utiliy and configuration items (imports, methods .etc).

# %%
# Imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Methods
def import_from_files_single_dataframe(rootdir):
    file_list =[]
    for dirpath, dirnames, filenames in os.walk(rootdir):
        for file in filenames:
            filename = os.path.join(dirpath, file)
            print(filename)
            file_list.append(filename)
            # read data from file

    df = pd.concat((pd.read_csv(f) for f in file_list), ignore_index=True)

    return df

#Utilities
DATASET_DIR = './UWB_LOS_NLOS_Data_Set/dataset/'

# %% [markdown]
# ### Data Importing/Merging
#
# This code block utilized the `import_from_files_single_dataframe` to import/load the dataset from the specified directory(`./UWB_LOS_NLOS_Data_Set/dataset/`).
#
# The directory contains 7 .csv dataset files, each coming from a different indoor environment:
#
# 1. Office 1
# 2. Office 2
# 3. Small Apartment
# 4. Small Workshop
# 5. Kitchen with a living room
# 6. Bedroom
# 7. Boiler room
#
# While each specific environment may have unique effects on the CIR measurements, the primary goal of this mini-project is to distinguish between Line-of-Sight (LOS) and Non-Line-of-Sight (NLOS) conditions based on the CIR readings. Since all the environments the data is collected from are indoor environments, it is reasonable to aggregate them together for further analysis, focusing primary on the distinction between LOS and NLOS conditions.

# %%
# Import raw data from folder with dataset
print("Importing dataset to Pandas dataframe")
print("-------------------------------")
df = import_from_files_single_dataframe(DATASET_DIR)

# Displays the concat data and the Head (First 5 rows of dataset) and Tail (Last 5 rows of dataset)
print("\nDataset:")
print("-------------------------------")
print(df)
# Out:
# Importing dataset to Pandas dataframe
# -------------------------------
# ./UWB_LOS_NLOS_Data_Set/dataset/uwb_dataset_part1.csv
# ./UWB_LOS_NLOS_Data_Set/dataset/uwb_dataset_part2.csv
# ./UWB_LOS_NLOS_Data_Set/dataset/uwb_dataset_part3.csv
# ./UWB_LOS_NLOS_Data_Set/dataset/uwb_dataset_part4.csv
# ./UWB_LOS_NLOS_Data_Set/dataset/uwb_dataset_part5.csv
# ./UWB_LOS_NLOS_Data_Set/dataset/uwb_dataset_part6.csv
# ./UWB_LOS_NLOS_Data_Set/dataset/uwb_dataset_part7.csv
#
# Dataset:
# -------------------------------
#        NLOS  RANGE  FP_IDX  FP_AMP1  FP_AMP2  FP_AMP3  STDEV_NOISE  CIR_PWR  \
# 0       0.0   3.90   745.0  18712.0  10250.0  11576.0         64.0  11855.0
# 1       0.0   0.66   749.0  11239.0   6313.0   4712.0         64.0  18968.0
# 2       1.0   7.86   746.0   4355.0   5240.0   3478.0         60.0  14699.0
# 3       1.0   3.48   750.0   8502.0   8416.0   5890.0         76.0   8748.0
# 4       0.0   1.19   746.0  17845.0  18095.0  12058.0         68.0  11380.0
# ...     ...    ...     ...      ...      ...      ...          ...      ...
# 41995   0.0   2.43   745.0  12960.0  17703.0  14948.0         96.0   9987.0
# 41996   0.0   1.39   745.0   2235.0  15089.0   8796.0         76.0  12559.0
# 41997   1.0   5.48   747.0   7115.0   6262.0   4584.0         72.0   1435.0
# 41998   1.0   3.40   745.0   6662.0   7683.0   5600.0         72.0   1491.0
# 41999   0.0   2.43   747.0   2621.0  10276.0   6284.0         56.0   9116.0
#
#        MAX_NOISE  RXPACC  ...  CIR1006  CIR1007  CIR1008  CIR1009  CIR1010  \
# 0          967.0   611.0  ...    279.0    458.0    183.0    158.0    198.0
# 1         1133.0   447.0  ...    144.0    334.0    290.0    228.0    187.0
# 2          894.0   723.0  ...     32.0    373.0    224.0    174.0    124.0
# 3         1127.0  1024.0  ...    252.0    173.0    198.0    160.0    434.0
# 4         1744.0   276.0  ...    154.0    209.0    242.0    296.0     87.0
# ...          ...     ...  ...      ...      ...      ...      ...      ...
# 41995     2379.0   276.0  ...    180.0    156.0    322.0    378.0    115.0
# 41996     1810.0   281.0  ...     43.0    433.0    517.0    518.0    287.0
# 41997     1092.0  1024.0  ...    394.0    475.0    262.0    468.0    247.0
# 41998     1077.0  1024.0  ...    397.0    170.0    231.0    231.0    202.0
# 41999     1224.0   342.0  ...    121.0    200.0    263.0    166.0    234.0
#
#        CIR1011  CIR1012  CIR1013  CIR1014  CIR1015
# 0         87.0    296.0    505.0    307.0      0.0
# 1        213.0    202.0     89.0    103.0      0.0
# 2        329.0    207.0     96.0    218.0      0.0
# 3        397.0    290.0    155.0    342.0    256.0
# 4        178.0    314.0    247.0    292.0    256.0
# ...        ...      ...      ...      ...      ...
# 41995    296.0    452.0    138.0    123.0      0.0
# 41996    169.0    437.0     59.0    296.0      0.0
# 41997    192.0    395.0    335.0    284.0    256.0
# 41998    253.0    128.0    311.0    290.0      0.0
# 41999     76.0    150.0    241.0    252.0    256.0
#
# [42000 rows x 1031 columns]

# %% [markdown]
# ### General Sanity Check
#
# From the output above, we can see that the data imported/loaded (into dataframe `df`) generally matches with the description in the Mini-Project Description Document. There are all together 42000 samples, with 15 featues and 1 class (1 Class + 14 Single Dimension Features + (1 Feature x 1016 Samples/Dimensions)), which tallies up with the shape (42000 rows x 1031 columns) of the dataframe.
#
# We can also observe that NLOS/LOS class distribution tallies with the numbers described in the Mini-Project Description Document (21000 for LOS and 21000 for NLOS channel condition)
#
# Additional information about the dataframe can also be used to verify the validity of the data imported/loaded (The column, non-null count & datatype)

# %%
# Displays the shape of the dataset
print("\nDataset shape:")
print("-------------------------------")
print(df.shape)

# Check LOS/NLOS Distribution
print("\nNLOS distribution:")
print("-------------------------------")
print(df['NLOS'].value_counts(), end='\n')

# Displays general information of the dataset
print("\nDataset data types:")
print("-------------------------------")
print(df.info(
    verbose=True,
    show_counts=True,
    )
)
# Out:
# Dataset shape:
# -------------------------------
# (42000, 1031)
#
# NLOS distribution:
# -------------------------------
# NLOS
# 0.0    21000
# 1.0    21000
# Name: count, dtype: int64
#
# Dataset data types:
# -------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42000 entries, 0 to 41999
# Data columns (total 1031 columns):
#  #     Column       Non-Null Count  Dtype
# ---    ------       --------------  -----
#  0     NLOS         42000 non-null  float64
#  1     RANGE        42000 non-null  float64
#  2     FP_IDX       42000 non-null  float64
#  3     FP_AMP1      42000 non-null  float64
#  4     FP_AMP2      42000 non-null  float64
#  5     FP_AMP3      42000 non-null  float64
#  6     STDEV_NOISE  42000 non-null  float64
#  7     CIR_PWR      42000 non-null  float64
#  8     MAX_NOISE    42000 non-null  float64
#  9     RXPACC       42000 non-null  float64
#  10    CH           42000 non-null  float64
#  11    FRAME_LEN    42000 non-null  float64
#  12    PREAM_LEN    42000 non-null  float64
#  13    BITRATE      42000 non-null  float64
#  14    PRFR         42000 non-null  float64
#  15    CIR0         42000 non-null  float64
#  16    CIR1         42000 non-null  float64
#  17    CIR2         42000 non-null  float64
#  18    CIR3         42000 non-null  float64
#  19    CIR4         42000 non-null  float64
#  20    CIR5         42000 non-null  float64
#  21    CIR6         42000 non-null  float64
#  22    CIR7         42000 non-null  float64
#  23    CIR8         42000 non-null  float64
#  24    CIR9         42000 non-null  float64
#  25    CIR10        42000 non-null  float64
#  26    CIR11        42000 non-null  float64
#  27    CIR12        42000 non-null  float64
#  28    CIR13        42000 non-null  float64
#  29    CIR14        42000 non-null  float64
#  30    CIR15        42000 non-null  float64
#  31    CIR16        42000 non-null  float64
#  32    CIR17        42000 non-null  float64
#  33    CIR18        42000 non-null  float64
#  34    CIR19        42000 non-null  float64
#  35    CIR20        42000 non-null  float64
#  36    CIR21        42000 non-null  float64
#  37    CIR22        42000 non-null  float64
#  38    CIR23        42000 non-null  float64
#  39    CIR24        42000 non-null  float64
#  40    CIR25        42000 non-null  float64
#  41    CIR26        42000 non-null  float64
#  42    CIR27        42000 non-null  float64
#  43    CIR28        42000 non-null  float64
#  44    CIR29        42000 non-null  float64
#  45    CIR30        42000 non-null  float64
#  46    CIR31        42000 non-null  float64
#  47    CIR32        42000 non-null  float64
#  48    CIR33        42000 non-null  float64
#  49    CIR34        42000 non-null  float64
#  50    CIR35        42000 non-null  float64
#  51    CIR36        42000 non-null  float64
#  52    CIR37        42000 non-null  float64
#  53    CIR38        42000 non-null  float64
#  54    CIR39        42000 non-null  float64
#  55    CIR40        42000 non-null  float64
#  56    CIR41        42000 non-null  float64
#  57    CIR42        42000 non-null  float64
#  58    CIR43        42000 non-null  float64
#  59    CIR44        42000 non-null  float64
#  60    CIR45        42000 non-null  float64
#  61    CIR46        42000 non-null  float64
#  62    CIR47        42000 non-null  float64
#  63    CIR48        42000 non-null  float64
#  64    CIR49        42000 non-null  float64
#  65    CIR50        42000 non-null  float64
#  66    CIR51        42000 non-null  float64
#  67    CIR52        42000 non-null  float64
#  68    CIR53        42000 non-null  float64
#  69    CIR54        42000 non-null  float64
#  70    CIR55        42000 non-null  float64
#  71    CIR56        42000 non-null  float64
#  72    CIR57        42000 non-null  float64
#  73    CIR58        42000 non-null  float64
#  74    CIR59        42000 non-null  float64
#  75    CIR60        42000 non-null  float64
#  713   CIR698       42000 non-null  float64
#  714   CIR699       42000 non-null  float64
#  715   CIR700       42000 non-null  float64
#  716   CIR701       42000 non-null  float64
#  717   CIR702       42000 non-null  float64
#  718   CIR703       42000 non-null  float64
#  719   CIR704       42000 non-null  float64
#  720   CIR705       42000 non-null  float64
#  721   CIR706       42000 non-null  float64
#  722   CIR707       42000 non-null  float64
#  723   CIR708       42000 non-null  float64
#  724   CIR709       42000 non-null  float64
#  725   CIR710       42000 non-null  float64
#  726   CIR711       42000 non-null  float64
#  727   CIR712       42000 non-null  float64
#  728   CIR713       42000 non-null  float64
#  729   CIR714       42000 non-null  float64
#  730   CIR715       42000 non-null  float64
#  731   CIR716       42000 non-null  float64
#  732   CIR717       42000 non-null  float64
#  733   CIR718       42000 non-null  float64
#  734   CIR719       42000 non-null  float64
#  735   CIR720       42000 non-null  float64
#  736   CIR721       42000 non-null  float64
#  737   CIR722       42000 non-null  float64
#  738   CIR723       42000 non-null  float64
#  739   CIR724       42000 non-null  float64
#  740   CIR725       42000 non-null  float64
#  741   CIR726       42000 non-null  float64
#  742   CIR727       42000 non-null  float64
#  743   CIR728       42000 non-null  float64
#  744   CIR729       42000 non-null  float64
#  745   CIR730       42000 non-null  float64
#  746   CIR731       42000 non-null  float64
#  747   CIR732       42000 non-null  float64
#  748   CIR733       42000 non-null  float64
#  749   CIR734       42000 non-null  float64
#  750   CIR735       42000 non-null  float64
#  751   CIR736       42000 non-null  float64
#  752   CIR737       42000 non-null  float64
#  753   CIR738       42000 non-null  float64
#  754   CIR739       42000 non-null  float64
#  755   CIR740       42000 non-null  float64
#  756   CIR741       42000 non-null  float64
#  757   CIR742       42000 non-null  float64
#  758   CIR743       42000 non-null  float64
#  759   CIR744       42000 non-null  float64
#  760   CIR745       42000 non-null  float64
#  761   CIR746       42000 non-null  float64
#  762   CIR747       42000 non-null  float64
#  763   CIR748       42000 non-null  float64
#  764   CIR749       42000 non-null  float64
#  765   CIR750       42000 non-null  float64
#  766   CIR751       42000 non-null  float64
#  767   CIR752       42000 non-null  float64
#  768   CIR753       42000 non-null  float64
#  769   CIR754       42000 non-null  float64
#  770   CIR755       42000 non-null  float64
#  771   CIR756       42000 non-null  float64
#  772   CIR757       42000 non-null  float64
#  773   CIR758       42000 non-null  float64
#  774   CIR759       42000 non-null  float64
#  775   CIR760       42000 non-null  float64
#  776   CIR761       42000 non-null  float64
#  777   CIR762       42000 non-null  float64
#  778   CIR763       42000 non-null  float64
#  779   CIR764       42000 non-null  float64
#  780   CIR765       42000 non-null  float64
#  781   CIR766       42000 non-null  float64
#  782   CIR767       42000 non-null  float64
#  783   CIR768       42000 non-null  float64
#  784   CIR769       42000 non-null  float64
#  785   CIR770       42000 non-null  float64
#  786   CIR771       42000 non-null  float64
#  787   CIR772       42000 non-null  float64
#  788   CIR773       42000 non-null  float64
#  789   CIR774       42000 non-null  float64
#  790   CIR775       42000 non-null  float64
#  791   CIR776       42000 non-null  float64
#  792   CIR777       42000 non-null  float64
#  953   CIR938       42000 non-null  float64
#  954   CIR939       42000 non-null  float64
#  955   CIR940       42000 non-null  float64
#  956   CIR941       42000 non-null  float64
#  957   CIR942       42000 non-null  float64
#  958   CIR943       42000 non-null  float64
#  959   CIR944       42000 non-null  float64
#  960   CIR945       42000 non-null  float64
#  961   CIR946       42000 non-null  float64
#  962   CIR947       42000 non-null  float64
#  963   CIR948       42000 non-null  float64
#  964   CIR949       42000 non-null  float64
#  965   CIR950       42000 non-null  float64
#  966   CIR951       42000 non-null  float64
#  967   CIR952       42000 non-null  float64
#  968   CIR953       42000 non-null  float64
#  969   CIR954       42000 non-null  float64
#  970   CIR955       42000 non-null  float64
#  971   CIR956       42000 non-null  float64
#  972   CIR957       42000 non-null  float64
#  973   CIR958       42000 non-null  float64
#  974   CIR959       42000 non-null  float64
#  975   CIR960       42000 non-null  float64
#  976   CIR961       42000 non-null  float64
#  977   CIR962       42000 non-null  float64
#  978   CIR963       42000 non-null  float64
#  979   CIR964       42000 non-null  float64
#  980   CIR965       42000 non-null  float64
#  981   CIR966       42000 non-null  float64
#  982   CIR967       42000 non-null  float64
#  983   CIR968       42000 non-null  float64
#  984   CIR969       42000 non-null  float64
#  985   CIR970       42000 non-null  float64
#  986   CIR971       42000 non-null  float64
#  987   CIR972       42000 non-null  float64
#  988   CIR973       42000 non-null  float64
#  989   CIR974       42000 non-null  float64
#  990   CIR975       42000 non-null  float64
#  991   CIR976       42000 non-null  float64
#  992   CIR977       42000 non-null  float64
#  993   CIR978       42000 non-null  float64
#  994   CIR979       42000 non-null  float64
#  995   CIR980       42000 non-null  float64
#  996   CIR981       42000 non-null  float64
#  997   CIR982       42000 non-null  float64
#  998   CIR983       42000 non-null  float64
#  999   CIR984       42000 non-null  float64
#  1000  CIR985       42000 non-null  float64
#  1001  CIR986       42000 non-null  float64
#  1002  CIR987       42000 non-null  float64
#  1003  CIR988       42000 non-null  float64
#  1004  CIR989       42000 non-null  float64
#  1005  CIR990       42000 non-null  float64
#  1006  CIR991       42000 non-null  float64
#  1007  CIR992       42000 non-null  float64
#  1008  CIR993       42000 non-null  float64
#  1009  CIR994       42000 non-null  float64
#  1010  CIR995       42000 non-null  float64
#  1011  CIR996       42000 non-null  float64
#  1012  CIR997       42000 non-null  float64
#  1013  CIR998       42000 non-null  float64
#  1014  CIR999       42000 non-null  float64
#  1015  CIR1000      42000 non-null  float64
#  1016  CIR1001      42000 non-null  float64
#  1017  CIR1002      42000 non-null  float64
#  1018  CIR1003      42000 non-null  float64
#  1019  CIR1004      42000 non-null  float64
#  1020  CIR1005      42000 non-null  float64
#  1021  CIR1006      42000 non-null  float64
#  1022  CIR1007      42000 non-null  float64
#  1023  CIR1008      42000 non-null  float64
#  1024  CIR1009      42000 non-null  float64
#  1025  CIR1010      42000 non-null  float64
#  1026  CIR1011      42000 non-null  float64
#  1027  CIR1012      42000 non-null  float64
#  1028  CIR1013      42000 non-null  float64
#  1029  CIR1014      42000 non-null  float64
#  1030  CIR1015      42000 non-null  float64
# dtypes: float64(1031)
# memory usage: 330.4 MB
# None

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Missing Data check/treatment
#
# This code block checks if there are any missing values ('Nulls' or 'NA') in the dataset.
#
# On analysis, there does not seem to be any missing values in the dataset, we can continue to proceed without treating the dataset for missing values

# %%
# Check if where are any nulls or missing values in dataset

print("\nAre Missing Values detected in dataframe: ", df.isnull().values.any())

print("\nNumber of Missing Values detected in dataframe by attribute:")
print("-------------------------------")
print(df.isnull().isna().sum())
# Out:
# Are Missing Values detected in dataframe:  False
#
# Number of Missing Values detected in dataframe by attribute:
# -------------------------------
# NLOS       0
# RANGE      0
# FP_IDX     0
# FP_AMP1    0
# FP_AMP2    0
#           ..
# CIR1011    0
# CIR1012    0
# CIR1013    0
# CIR1014    0
# CIR1015    0
# Length: 1031, dtype: int64

# %% [markdown]
# ### Duplicate Data check/treatment
#
# This code block checks if there are any duplicate values in the dataset.
#
# On analysis, there does not seem to be any duplicate values in the dataset, we can continue to proceed without treating the dataset for duplicates.

# %%
# Check if there are duplicates in dataset

print("\nAre Duplicates detected in dataframe: ", df.duplicated().values.any())

print("\nNumber of Duplicates detected in dataframe by attribute:")
print("-------------------------------")
print(df.duplicated().sum())
# Out:
# Are Duplicates detected in dataframe:  False
#
# Number of Duplicates detected in dataframe by attribute:
# -------------------------------
# 0

# %% [markdown]
# ### Outlier Data check/treatment

# %%
# Might eliminate this section if a good reason to eliminate outliers cannot be found

# %% [markdown]
# ## Data Exploration and Feature Extraction

# %% [markdown]
# For pre-processing purposes, we can generally break down the dataset into 2 groups: **CIR (Channel Impulse Response)** and **Non-CIR**.
#
# Referencing the authors' description as well as other research [1][4], a discription of the 2 groups and their composite features are as such:
#
# <ins>CIR group</ins>
# - `CIR0` to `CIR1015` (1016 samples with 1 nano-second resolution)
#
# <ins>Non-CIR group</ins>
# - Class Feature
#     - `NLOS` : Indicates LOS/NLOS Class (0: LOS, 1: NLOS)
# - Frame Quality Indicators (quality of messages received [2])
#     - `RANGE` : Measured range (time of flight)
#     - `FP_IDX` (First Power Index) : Index of detected first path element in CIR accumulator (**16-bit value** reporting the position within the accumulator that the Leading Edge (LDE) algorithm has determined to be the first path)
#     - `FP_AMP1` : The amplitude of the sample reported is the magnitude of the accumulator tap at the **index 1** beyond the integer portion of the rising edge `FP_IDX`.
#     - `FP_AMP2` :  The amplitude of the sample reported is the magnitude of the accumulator tap at the **index 2** beyond the integer portion of the rising edge `FP_IDX`.
#     - `FP_AMP3` : The amplitude of the sample reported is the magnitude of the accumulator tap at the **index 3** beyond the integer portion of the rising edge `FP_IDX`.
#     - `STDEV_NOISE` : Standard Deviation of CIR Estimate Noise (**16-bit value** reporting the standard deviation of the noise level seen during the LDE algorithm’s analysis of the accumulator data)
#     - `CIR_PWR` : Total Channel Impulse Response Power (**16-bit value** reporting the sum of the squares of the magnitudes of the accumulator from the estimated highest power portion of the channel, which is related to the receive signal power)
#     - `MAX_NOISE` : Maximum value of noise detected
#     - `RXPACC` : Received RX preamble symbols (Preamble Accumulation Count)
#     - `CH` : Channel value
#     - `FRAME_LEN` : Length of frame
#     - `PREAM_LEN`: Length of preamble
#     - `BITRATE` : Message's bit rate
#     - `PRFR` : Pulse Repetition Frequency Rate (Mhz)
#
# Note that the 'CIR' features group mainly looks to isolate the 1016 samples of the absolute value of channel impulse response, hence the grouping of the 'CIR_PWR' feature under the 'Non-CIR' feature group. This is done in order to facilitate further feature extraction pertaining to the estimated receive power figure which will be explained further below.

# %%
# Separate the data into LOS and NLOS
df_nlos_group = df.iloc[:, :15].copy()
df_los_group = df.iloc[:, 15:].copy()

# %%
print("\nNLOS Group:")
print("-------------------------------")
df_nlos_group
# Out:
# NLOS Group:
# -------------------------------
#        NLOS  RANGE  FP_IDX  FP_AMP1  FP_AMP2  FP_AMP3  STDEV_NOISE  CIR_PWR  \
# 0       0.0   3.90   745.0  18712.0  10250.0  11576.0         64.0  11855.0
# 1       0.0   0.66   749.0  11239.0   6313.0   4712.0         64.0  18968.0
# 2       1.0   7.86   746.0   4355.0   5240.0   3478.0         60.0  14699.0
# 3       1.0   3.48   750.0   8502.0   8416.0   5890.0         76.0   8748.0
# 4       0.0   1.19   746.0  17845.0  18095.0  12058.0         68.0  11380.0
# ...     ...    ...     ...      ...      ...      ...          ...      ...
# 41995   0.0   2.43   745.0  12960.0  17703.0  14948.0         96.0   9987.0
# 41996   0.0   1.39   745.0   2235.0  15089.0   8796.0         76.0  12559.0
# 41997   1.0   5.48   747.0   7115.0   6262.0   4584.0         72.0   1435.0
# 41998   1.0   3.40   745.0   6662.0   7683.0   5600.0         72.0   1491.0
# 41999   0.0   2.43   747.0   2621.0  10276.0   6284.0         56.0   9116.0
#
#        MAX_NOISE  RXPACC   CH  FRAME_LEN  PREAM_LEN  BITRATE  PRFR
# 0          967.0   611.0  2.0       39.0     1024.0    110.0  64.0
# 1         1133.0   447.0  2.0       27.0     1024.0    110.0  64.0
# 2          894.0   723.0  2.0       27.0     1024.0    110.0  64.0
# 3         1127.0  1024.0  2.0       39.0     1024.0    110.0  64.0
# 4         1744.0   276.0  2.0       27.0     1024.0    110.0  64.0
# ...          ...     ...  ...        ...        ...      ...   ...
# 41995     2379.0   276.0  2.0       27.0     1024.0    110.0  64.0
# 41996     1810.0   281.0  2.0       39.0     1024.0    110.0  64.0
# 41997     1092.0  1024.0  2.0       39.0     1024.0    110.0  64.0
# 41998     1077.0  1024.0  2.0       27.0     1024.0    110.0  64.0
# 41999     1224.0   342.0  2.0       27.0     1024.0    110.0  64.0
#
# [42000 rows x 15 columns]

# %%
print("\nLOS Group:")
print("-------------------------------")
df_los_group
# Out:
# LOS Group:
# -------------------------------
#         CIR0   CIR1   CIR2   CIR3   CIR4   CIR5   CIR6   CIR7   CIR8   CIR9  \
# 0      129.0  312.0  331.0  141.0  160.0  488.0  195.0  144.0  119.0  193.0
# 1      117.0  163.0  199.0  136.0  142.0  182.0  358.0  123.0  280.0  311.0
# 2      433.0  240.0  233.0   81.0  143.0  506.0  119.0  272.0  248.0  233.0
# 3      466.0  247.0  407.0  225.0  279.0   69.0  393.0  436.0  289.0  169.0
# 4      259.0  239.0   57.0   19.0   88.0  219.0  400.0  151.0   98.0  415.0
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 41995  202.0  224.0   51.0  300.0  284.0  446.0  425.0  252.0  189.0  162.0
# 41996  190.0  153.0  199.0   85.0  167.0  268.0  298.0  228.0  185.0  234.0
# 41997  504.0  363.0  188.0  150.0  260.0  262.0  159.0  480.0  455.0  225.0
# 41998  337.0  396.0  243.0  245.0  105.0  182.0  397.0  293.0   78.0  203.0
# 41999  187.0  313.0  213.0  256.0  254.0  183.0   37.0   77.0  183.0  323.0
#
#        ...  CIR1006  CIR1007  CIR1008  CIR1009  CIR1010  CIR1011  CIR1012  \
# 0      ...    279.0    458.0    183.0    158.0    198.0     87.0    296.0
# 1      ...    144.0    334.0    290.0    228.0    187.0    213.0    202.0
# 2      ...     32.0    373.0    224.0    174.0    124.0    329.0    207.0
# 3      ...    252.0    173.0    198.0    160.0    434.0    397.0    290.0
# 4      ...    154.0    209.0    242.0    296.0     87.0    178.0    314.0
# ...    ...      ...      ...      ...      ...      ...      ...      ...
# 41995  ...    180.0    156.0    322.0    378.0    115.0    296.0    452.0
# 41996  ...     43.0    433.0    517.0    518.0    287.0    169.0    437.0
# 41997  ...    394.0    475.0    262.0    468.0    247.0    192.0    395.0
# 41998  ...    397.0    170.0    231.0    231.0    202.0    253.0    128.0
# 41999  ...    121.0    200.0    263.0    166.0    234.0     76.0    150.0
#
#        CIR1013  CIR1014  CIR1015
# 0        505.0    307.0      0.0
# 1         89.0    103.0      0.0
# 2         96.0    218.0      0.0
# 3        155.0    342.0    256.0
# 4        247.0    292.0    256.0
# ...        ...      ...      ...
# 41995    138.0    123.0      0.0
# 41996     59.0    296.0      0.0
# 41997    335.0    284.0    256.0
# 41998    311.0    290.0      0.0
# 41999    241.0    252.0    256.0
#
# [42000 rows x 1016 columns]

# %% [markdown]
# ### Feature Extraction

# %% [markdown]
# Existing literature on UWB LOS and NLOS classification often mentions the use of power measurements to differentiate between the two [5], and this method is also described in the Decawave DWM1000 user manual [3].
#
# The First Path Lower Level (FP), Received Signal Power Level (RX) and their derivative, the Threshold Power (RX-FP), can be derived by extracting and transforming the data from the FP_AMP1, 2, & 3 and CIR_power columns. This process essentially measures the power difference in the received signal. Logically, when the signal is blocked, the difference in power will be greater. A distance is classified as LOS when the threshold power (calculated using equation (3)) is less than 6 dBm, and as NLOS when it exceeds 10 dBm.

# %% [markdown]
# ![FP_formula.png](attachment:bb9f9551-58ee-4e72-90a9-8425e2f1ef52.png)

# %%
# Define value of constant A, based on pulse repetition frequency rate
constant_a = 121.74 if df_nlos_group['PRFR'][0] == 64.0 else 113.77 if df_nlos_group['PRFR'][0] == 16.0 else 0

# Compute numerator and denominator
numerator = (df_nlos_group['FP_AMP1']**2) + (df_nlos_group['FP_AMP2']**2) + (df_nlos_group['FP_AMP3']**2)
denominator = df_nlos_group['RXPACC']**2

# Compute FP_POWER (First Path Power Level), ensuring that the numerator is not 0 to prevent log10(0) error
df_nlos_group.loc[numerator != 0.0, 'FP_POWER'] = 10 * np.log10(numerator / denominator) - constant_a
df_nlos_group
# Out:
#        NLOS  RANGE  FP_IDX  FP_AMP1  FP_AMP2  FP_AMP3  STDEV_NOISE  CIR_PWR  \
# 0       0.0   3.90   745.0  18712.0  10250.0  11576.0         64.0  11855.0
# 1       0.0   0.66   749.0  11239.0   6313.0   4712.0         64.0  18968.0
# 2       1.0   7.86   746.0   4355.0   5240.0   3478.0         60.0  14699.0
# 3       1.0   3.48   750.0   8502.0   8416.0   5890.0         76.0   8748.0
# 4       0.0   1.19   746.0  17845.0  18095.0  12058.0         68.0  11380.0
# ...     ...    ...     ...      ...      ...      ...          ...      ...
# 41995   0.0   2.43   745.0  12960.0  17703.0  14948.0         96.0   9987.0
# 41996   0.0   1.39   745.0   2235.0  15089.0   8796.0         76.0  12559.0
# 41997   1.0   5.48   747.0   7115.0   6262.0   4584.0         72.0   1435.0
# 41998   1.0   3.40   745.0   6662.0   7683.0   5600.0         72.0   1491.0
# 41999   0.0   2.43   747.0   2621.0  10276.0   6284.0         56.0   9116.0
#
#        MAX_NOISE  RXPACC   CH  FRAME_LEN  PREAM_LEN  BITRATE  PRFR    FP_POWER
# 0          967.0   611.0  2.0       39.0     1024.0    110.0  64.0  -89.758158
# 1         1133.0   447.0  2.0       27.0     1024.0    110.0  64.0  -91.995986
# 2          894.0   723.0  2.0       27.0     1024.0    110.0  64.0 -101.249715
# 3         1127.0  1024.0  2.0       39.0     1024.0    110.0  64.0  -99.446556
# 4         1744.0   276.0  2.0       27.0     1024.0    110.0  64.0  -81.574943
# ...          ...     ...  ...        ...        ...      ...   ...         ...
# 41995     2379.0   276.0  2.0       27.0     1024.0    110.0  64.0  -82.077520
# 41996     1810.0   281.0  2.0       39.0     1024.0    110.0  64.0  -85.799910
# 41997     1092.0  1024.0  2.0       39.0     1024.0    110.0  64.0 -101.498684
# 41998     1077.0  1024.0  2.0       27.0     1024.0    110.0  64.0 -100.650043
# 41999     1224.0   342.0  2.0       27.0     1024.0    110.0  64.0  -90.603387
#
# [42000 rows x 16 columns]

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
# Description of dataset
df_nlos_group.describe()
# Out:
#                NLOS         RANGE        FP_IDX       FP_AMP1       FP_AMP2  \
# count  42000.000000  42000.000000  42000.000000  42000.000000  42000.000000
# mean       0.500000      3.831519    745.654167   8127.521905  11425.259524
# std        0.500006      2.355976      4.505024   5393.330697   6235.434769
# min        0.000000      0.000000    707.000000      7.000000     63.000000
# 25%        0.000000      1.810000    744.000000   3573.750000   5322.750000
# 50%        0.500000      3.480000    746.000000   7140.000000  12318.000000
# 75%        1.000000      5.420000    748.000000  12273.000000  17310.000000
# max        1.000000     28.020000    848.000000  20572.000000  20624.000000
#
#             FP_AMP3   STDEV_NOISE       CIR_PWR     MAX_NOISE       RXPACC  \
# count  42000.000000  42000.000000  42000.000000  42000.000000  42000.00000
# mean    9738.106048     72.284571   9789.690214   1316.096524    616.27250
# std     5352.311549     29.318995   4912.556005    582.434989    306.78537
# min      187.000000     28.000000      0.000000    310.000000    128.00000
# 25%     4723.000000     56.000000   6727.000000    961.000000    318.00000
# 50%    10262.000000     68.000000   9950.500000   1134.000000    513.00000
# 75%    14256.000000     80.000000  12443.000000   1488.000000   1024.00000
# max    20577.000000    324.000000  37208.000000   5169.000000   1056.00000
#
#             CH     FRAME_LEN     PREAM_LEN  BITRATE     PRFR
# count  42000.0  42000.000000  42000.000000  42000.0  42000.0
# mean       2.0     33.801762   1042.980571    110.0     64.0
# std        0.0      5.946221     96.736825      0.0      0.0
# min        2.0     27.000000   1024.000000    110.0     64.0
# 25%        2.0     27.000000   1024.000000    110.0     64.0
# 50%        2.0     39.000000   1024.000000    110.0     64.0
# 75%        2.0     39.000000   1024.000000    110.0     64.0
# max        2.0     39.000000   1536.000000    110.0     64.0

# %% [markdown]
# Looking at the description of the filtered/aggregated dataframe, we can see that CH, BITRATE and PRFR have a Standard Deviation of 0, this implies that all elements in the column are equal. We can presumably discard these values as they will not offer any meaningful insight into the data.

# %%
df_nlos_group.drop(columns=['CH', 'BITRATE', 'PRFR'], errors='ignore')
# Out:
#        NLOS  RANGE  FP_IDX  FP_AMP1  FP_AMP2  FP_AMP3  STDEV_NOISE  CIR_PWR  \
# 0       0.0   3.90   745.0  18712.0  10250.0  11576.0         64.0  11855.0
# 1       0.0   0.66   749.0  11239.0   6313.0   4712.0         64.0  18968.0
# 2       1.0   7.86   746.0   4355.0   5240.0   3478.0         60.0  14699.0
# 3       1.0   3.48   750.0   8502.0   8416.0   5890.0         76.0   8748.0
# 4       0.0   1.19   746.0  17845.0  18095.0  12058.0         68.0  11380.0
# ...     ...    ...     ...      ...      ...      ...          ...      ...
# 41995   0.0   2.43   745.0  12960.0  17703.0  14948.0         96.0   9987.0
# 41996   0.0   1.39   745.0   2235.0  15089.0   8796.0         76.0  12559.0
# 41997   1.0   5.48   747.0   7115.0   6262.0   4584.0         72.0   1435.0
# 41998   1.0   3.40   745.0   6662.0   7683.0   5600.0         72.0   1491.0
# 41999   0.0   2.43   747.0   2621.0  10276.0   6284.0         56.0   9116.0
#
#        MAX_NOISE  RXPACC  FRAME_LEN  PREAM_LEN
# 0          967.0   611.0       39.0     1024.0
# 1         1133.0   447.0       27.0     1024.0
# 2          894.0   723.0       27.0     1024.0
# 3         1127.0  1024.0       39.0     1024.0
# 4         1744.0   276.0       27.0     1024.0
# ...          ...     ...        ...        ...
# 41995     2379.0   276.0       27.0     1024.0
# 41996     1810.0   281.0       39.0     1024.0
# 41997     1092.0  1024.0       39.0     1024.0
# 41998     1077.0  1024.0       27.0     1024.0
# 41999     1224.0   342.0       27.0     1024.0
#
# [42000 rows x 12 columns]

# %%
# Histogram of dataset to understand distribution except for NLOS (Label)
print("\nHistogram of dataset to understand distribution except for NLOS (Label):")
print("-------------------------------")
for i in filtered_df.columns:
    if i != "NLOS":
        sns.histplot(data=filtered_df, x=i)
        plt.show()

# Boxplot of dataset to identify outliers
print("\nBoxplot of dataset to identify outliers:")
print("-------------------------------")
for i in filtered_df.columns:
    if i != "NLOS":
        sns.boxplot(data=filtered_df, x=i)
        plt.show()

# Correlation with heatmap to identify and investigate relationships
print("\nCorrelation with heatmap to identify and investigate relationships:")
print("-------------------------------")
plt.figure(figsize=(12, 8))
plt.title("Feature Correlation Heatmap")
sns.heatmap(filtered_df.corr(), annot=True, fmt='.2f', linewidths=0.5)
plt.show()
# Out:
# Histogram of dataset to understand distribution except for NLOS (Label):
# -------------------------------
# Boxplot of dataset to identify outliers:
# -------------------------------
# Correlation with heatmap to identify and investigate relationships:
# -------------------------------

# %% [markdown]
# ### Principle Component Analysis (PCA)

# %% [markdown]
# We have to first split the Class label from the data before performing PCA

# %%
# Define Data (X) and Class Labels (y)
X = filtered_df.iloc[:, 1:13]  
Y = filtered_df.iloc[:, 0]

# %%
from sklearn.decomposition import PCA

pca = PCA()
pca.fit(X)
projected = pca.transform(X)

columnLabels = []
for i in range (1, X.shape[1]+1):
    columnLabels.append("pc" + str(i))

projected_1 = pd.DataFrame(projected,columns=columnLabels,index=range(1,X.shape[0]+1))

projected_1
# Out:
#                 pc1           pc2          pc3          pc4         pc5  \
# 1       5445.108997   4495.126105  7513.385324  3803.424793 -618.373988
# 2      -1899.589872  11880.298202   753.262441   -19.677570 -173.085823
# 3      -7570.064669   7073.485647 -2686.311497 -1162.944230 -253.554548
# 4      -4198.626983   1398.252051  2279.379910  -620.451931 -168.009007
# 5      10352.466712   1189.920608  6074.204447 -1261.516173  206.115856
# ...             ...           ...          ...          ...         ...
# 41996   9096.995883  -2140.436782  1708.492385   318.765892  907.600775
# 41997    191.159116   -164.086405 -6190.289679 -4254.634233  671.128470
# 41998  -9137.510618  -4091.389518  4896.180613   -19.838755 -174.815171
# 41999  -7841.698397  -4946.571562  4028.834508  -331.150656 -192.902598
# 42000  -5200.188034   -645.171805 -3116.824670 -2598.943133   84.558573
#
#               pc6        pc7        pc8        pc9      pc10      pc11  \
# 1      153.407765 -10.236433   1.046892  11.321145  4.630817 -2.299458
# 2     -176.446429 -12.640521 -62.077004  14.140112 -5.820781  3.097501
# 3      -56.167614 -30.288033  13.809528  -3.468321 -6.337712  1.562723
# 4      306.116446 -55.917905 -45.928746   2.887520  3.945139  6.050810
# 5      -87.711030   9.014177 -26.902099  -2.348148 -6.642172 -1.427385
# ...           ...        ...        ...        ...       ...       ...
# 41996 -100.598287   4.767765  -1.260641  -9.969941 -6.349717 -2.640100
# 41997 -349.590047  -0.926104 -22.882339  -5.226244  6.204806 -0.582533
# 41998  178.305473 -56.286572  -6.123264  -1.979128  3.143606  4.162196
# 41999  192.298419 -57.499749 -49.415703   5.373859 -9.041575  1.827022
# 42000 -429.427110  -4.883557 -38.678415   4.976778 -6.723405  2.171452
#
#            pc12
# 1      0.690492
# 2     -1.919257
# 3      2.898190
# 4     -1.085186
# 5     -0.321073
# ...         ...
# 41996  0.727865
# 41997 -1.181944
# 41998  0.402069
# 41999 -1.271351
# 42000 -0.359782
#
# [42000 rows x 12 columns]

# %%
# calculate cumulative sum of explained variances
tot = sum(pca.explained_variance_)
print("Explained variances", pca.explained_variance_)
print("Sum of explained variances", tot)
var_exp = [(i/tot ) for i in sorted(pca.explained_variance_, reverse=True)]
cum_var_exp = np.cumsum(var_exp)
pc_count = len(var_exp)
print("PC count: ", pc_count)
# plot explained variances
plt.bar(range(1,pc_count+1), var_exp, alpha=0.5,
        align='center', label='individual explained variance')
plt.step(range(1,pc_count+1), cum_var_exp, where='mid',
         label='cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.legend(loc='best')
plt.show()
# Out:
# Explained variances [8.18489996e+07 1.86225561e+07 1.70735522e+07 3.27352639e+06
#  3.20228425e+05 5.18321232e+04 8.61901905e+03 1.77749620e+03
#  5.13261840e+01 3.27778170e+01 1.49455307e+01 2.60252807e+00]
# Sum of explained variances 121201193.05661501
# PC count:  12

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %% [markdown]
# From the PCA analysis, 3 PC components is sufficient to represent the entire variance of the data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## <u> Data Mining </u>

# %% [markdown]
# ### Data Sub-setting/Sampling (Training & Test)

# %%
from sklearn.model_selection import train_test_split

# Create the Training and Test set with split 70:30 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=12)

# Apply PCA
pca = PCA(n_components=3)
pca.fit(X_train)
X_train = pca.transform(X_train)
X_test = pca.transform(X_test)

# %% [markdown]
# ## Classification

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score

clf=DecisionTreeClassifier(max_depth=10)
clf.fit(X_train, Y_train)

# Predict and evaluate
Y_pred = clf.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")


# fig = plt.figure(figsize=(25,20))
# plot_tree(clf, filled=True, feature_names=X.columns, class_names=['LOS', 'NLOS'])
# Out:
# Accuracy: 77.01%

# %%
###########################################################################
# Model fit and performance evaluation for various tree depth from 2-50
###########################################################################

maxdepths = [2,3,4,5,6,7,8,9,10,15,20,25,30,35,40,45,50]

trainAccuracy = np.zeros(len(maxdepths))
testAccuracy = np.zeros(len(maxdepths))

index = 0
for depth in maxdepths:
    clf = DecisionTreeClassifier(max_depth=depth)
    clf = clf.fit(X_train, Y_train)
    Y_predTrain = clf.predict(X_train)
    Y_predTest = clf.predict(X_test)
    trainAccuracy[index] = accuracy_score(Y_train, Y_predTrain)
    testAccuracy[index] = accuracy_score(Y_test, Y_predTest)
    index += 1

###########################################################################
# Plot training and test accuracies
##########################################################################
    
plt.plot(maxdepths,trainAccuracy,'ro-',maxdepths,testAccuracy,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Max depth')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# Linear Support Vector Machine (SVM)

# %%
# from sklearn.svm import SVC

# C = [0.01, 0.1, 0.2, 0.5, 0.8, 1, 5, 10, 20, 50]

# SVMtrainAcc = []
# SVMtestAcc = []

# for param in C:
#     clf4 = SVC(C=param,kernel='linear')
#     clf4.fit(X_train, Y_train)
#     Y_predTrain_SVC = clf4.predict(X_train)
#     Y_predTest_SVC = clf4.predict(X_test)
#     SVMtrainAcc.append(accuracy_score(Y_train, Y_predTrain_SVC))
#     SVMtestAcc.append(accuracy_score(Y_test, Y_predTest_SVC))

# fig, (ax1) = plt.subplots(1, 1, figsize=(12,6))

# ax1.plot(C, SVMtrainAcc, 'ro-', C, SVMtestAcc,'bv--')
# ax1.legend(['Training Accuracy','Test Accuracy'])
# ax1.set_xlabel('C')
# ax1.set_xscale('log')
# ax1.set_ylabel('Accuracy')

# %% [markdown]
# K Nearest Neighbour (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt


numNeighbors = [1, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
trainAcc = []
testAcc = []

for k in numNeighbors:
    clf1 = KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=2)
    clf1.fit(X_train, Y_train)
    Y_predTrain_KNN = clf1.predict(X_train)
    Y_predTest_KNN = clf1.predict(X_test)
    trainAcc.append(accuracy_score(Y_train, Y_predTrain))
    testAcc.append(accuracy_score(Y_test, Y_predTest))

plt.plot(numNeighbors, trainAcc, 'ro-', numNeighbors, testAcc,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# Artificial Neural Network (ANN)

# %%
from sklearn.neural_network import MLPClassifier

hidden_layer_sizes = [(10,10,10), (20,20,20), (30,30,30), (40,40,40), (50,50,50), (60,60,60), (70,70,70)]
trainAcc = []
testAcc = []

for k in hidden_layer_sizes:
    clf6 = MLPClassifier(solver='adam',hidden_layer_sizes=k, learning_rate='adaptive',random_state=1,max_iter=1000)
    clf6.fit(X_train, Y_train)
    Y_predTrain = clf6.predict(X_train)
    Y_predTest = clf6.predict(X_test)
    trainAcc.append(accuracy_score(Y_train, Y_predTrain))
    testAcc.append(accuracy_score(Y_test, Y_predTest))
hidden_layer_size=[x[0] for x in hidden_layer_sizes]
plt.plot(hidden_layer_size, trainAcc, 'ro-', hidden_layer_size, testAcc,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Number of hidden layer')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# Comparison & Analysis (Classification)

# %% [markdown]
# ## Regression

# %% [markdown]
# This one is more complicated and needs more research

# %% [markdown]
# <hr>

# %% [markdown]
# ## <u> Data Post-Processing </u>

# %% [markdown]
# <hr>

# %% [markdown]
# # <u> References </u>
#
# [1] K. Bregar, A. Hrovat, and M. Mohorcic, “UWB LOS and NLOS Data Set,” GitHub, https://github.com/ewine-project/UWB-LOS-NLOS-Data-Set (accessed Mar. 10, 2025). <br>
# [2] K. Bregar, A. Hrovat, and M. Mohorcic, “NLOS Channel Detection with Multilayer Perceptron in Low-Rate Personal Area Networks for Indoor Localization Accuracy Improvement,” Jožef Stefan International Postgraduate School Student Conference, May 2016. [Online]. Available: https://www.researchgate.net/publication/308986067_NLOS_Channel_Detection_with_Multilayer_Perceptron_in_Low-Rate_Personal_Area_Networks_for_Indoor_Localization_Accuracy_Improvement <br>
# [3] D. Decawave, “DW1000 User Manual,” decaWave DW1000 User Manual, https://thetoolchain.com/mirror/dw1000/dw1000_user_manual_v2.05.pdf (accessed Mar. 10, 2025). <br>
# [4] Afandy, P. F., Pang Zi Jian, A., Lai Wei Shao, R., Yu Jie, T., & Tay Yong Jun, A. (n.d.). PTRPFA/UWB-Los-NLOS-classification: Classification of UWB samples from Decaware’s DWM1000 UWB transceivers into Los and NLOS. GitHub. https://github.com/ptrpfa/UWB-LOS-NLOS-Classification/tree/main (accessed Mar. 10, 2025) <br>
# [5] Sang, C. L., Steinhagen, B., Homburg, J. D., Adams, M., Hesse, M., & Rückert, U., June 2020. Identification of NLOS and multi-path conditions in UWB localization using machine learning methods. MDPI. https://www.mdpi.com/2076-3417/10/11/3980 (accessed Mar. 10, 2025)<br>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ee77a9d2-e617-4197-bdd4-20a2b8553e12' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
